# %%
import pandas as pd

# %%
file_path = '/Users/jnewman/Desktop/panama_data.xlsx'

# %%
# Returns a pandas dataframe..heres a 10 minute intro: (https://pandas.pydata.org/pandas-docs/stable/10min.html)
data = pd.read_excel(file_path, header=2)

# %%
data.shape # num_rows x num_columns
# Out:
# (691, 30)

# %%
data.columns
# Out:
# Index(['ano', 'mes', 'semana', 'codigo', 'enfermedad', 'F', 'M', 'F.1', 'M.1',
#        'F.2', 'M.2', 'F.3', 'M.3', 'F.4', 'M.4', 'F.5', 'M.5', 'F.6', 'M.6',
#        'F.7', 'M.7', 'F.8', 'M.8', 'F.9', 'M.9', 'F.10', 'M.10', 'mujeres',
#        'hombres', 'Unnamed: 29'],
#       dtype='object')

# %%
data
# Out:
#       ano  mes  semana codigo  \
# 0    2014    1       1  I10.X
# 1    2014    1       1  J00.X
# 2    2014    1       1  K02.1
# 3    2014    1       1  A08.4
# 4    2014    1       1  Z03.8
# 5    2014    1       1  L08.0
# 6    2014    1       4  K05.1
# 7    2014    1       1  J06.9
# 8    2014    1       2  E14.9
# 9    2014    1       1  R05.X
# 10   2014    1       1  B82.9
# 11   2014    1       2  N39.0
# 12   2014    1       2  M54.5
# 13   2014    1       3  J02.9
# 14   2014    1       3  Z12.4
# 15   2014    1       1  L02.8
# 16   2014    1       1  K02.0
# 17   2014    1       1  K05.3
# 18   2014    1       1  E66.9
# 19   2014    1       2  Z13.3
# 20   2014    1       3  S91.3
# 21   2014    1       3  G40.9
# 22   2014    1       1  T78.4
# 23   2014    1       2  B35.1
# 24   2014    1       1  N76.0
# 25   2014    1       2  T79.3
# 26   2014    1       2  K29.7
# 27   2014    1       4  J11.1
# 28   2014    1       5  T14.9
# 29   2014    1       1  I51.9
# ...

# %%
# summary of data
data.describe()
# Out:
#           ano         mes     semana           F           M         F.1  \
# count   691.0  691.000000  691.00000  691.000000  691.000000  691.000000
# mean   2014.0    4.102750   16.02026    0.041968    0.149059    0.451520
# std       0.0    2.324322   10.07319    0.335751    2.107147    2.930877
# min    2014.0    1.000000    1.00000    0.000000    0.000000    0.000000
# 25%    2014.0    2.000000    6.00000    0.000000    0.000000    0.000000
# 50%    2014.0    5.000000   20.00000    0.000000    0.000000    0.000000
# 75%    2014.0    6.000000   25.00000    0.000000    0.000000    0.000000
# max    2014.0    7.000000   31.00000    5.000000   54.000000   50.000000
#
#               M.1         F.2         M.2         F.3     ...       \
# count  691.000000  691.000000  691.000000  691.000000     ...
# mean     0.470333    0.409551    0.397974    0.331404     ...
# std      4.330234    2.198516    2.061221    3.512113     ...
# ...
